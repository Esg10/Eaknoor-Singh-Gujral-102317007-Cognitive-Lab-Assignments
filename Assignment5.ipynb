# %% [markdown]
# # Q.1 For the array gfg = np.matrix('[4, 1, 9; 12, 3, 1; 4, 5, 6]'), Find
# i. Sum of all elements
# ii. Sum of all elements row-wise
# iii. Sum of all elements column-wise *italicized text*

# %%
import numpy as np

gfg = np.matrix('[4, 1, 9; 12, 3, 1; 4, 5, 6]')
total_sum = np.sum(gfg)
print("Total Sum:", total_sum)
row_sum = np.sum(gfg, axis=1)
print("Row-wise Sum:\n", row_sum)
col_sum = np.sum(gfg, axis=0)
print("Column-wise Sum:\n", col_sum)
# Out:
# Total Sum: 45
# Row-wise Sum:
#  [[14]
#  [16]
#  [15]]
# Column-wise Sum:
#  [[20  9 16]]

# %% [markdown]
# #Q.2 (a)For the array: array = np.array([10, 52, 62, 16, 16, 54, 453]), find
# i. Sorted array
# ii. Indices of sorted array
# iii. 4 smallest elements
# iv. 5 largest elements *italicized text*

# %%
array = np.array([10, 52, 62, 16, 16, 54, 453])
sorted_array = np.sort(array)
print("Sorted Array:\n", sorted_array)
indices = np.argsort(array)
print("Indices of Sorted Array:\n", indices)
smallest_4 = sorted_array[:4]
print("4 Smallest Elements:\n", smallest_4)
largest_5 = sorted_array[-5:]
print("5 Largest Elements:\n", largest_5)
# Out:
# Sorted Array:
#  [ 10  16  16  52  54  62 453]
# Indices of Sorted Array:
#  [0 3 4 1 5 2 6]
# 4 Smallest Elements:
#  [10 16 16 52]
# 5 Largest Elements:
#  [ 16  52  54  62 453]

# %% [markdown]
# #Q2. (b) For the array: array = np.array([1.0, 1.2, 2.2, 2.0, 3.0, 2.0]), find
# i. Integer elements only
# ii. Float elements only

# %%
assd = np.array([1.0, 1.2, 2.2, 2.0, 3.0, 2.0])
integer_elements = assd[assd == assd.astype(int)]
print("Integer Elements:\n", integer_elements)
float_elements = assd[assd != assd.astype(int)]
print("Float Elements:\n", float_elements)
# Out:
# Integer Elements:
#  [1. 2. 3. 2.]
# Float Elements:
#  [1.2 2.2]

# %% [markdown]
# ![Screenshot 2025-02-05 at 10.52.32 AM.png](data:image/png;base64,...)

# %%
import numpy as np
X= ord('E')+ord('G')
sales = np.arange(X,X+(50*5),50)
print(sales)
tax_rate= sales * ((X%5)+5)/100
# sales = sales + tax
print(tax_rate)
discounted_sales = np.where(sales < X+100, sales * 0.95, sales * 0.90)
print(discounted_sales)
weekly_sales = np.tile(discounted_sales, (3, 1))
weeks = np.arange(3).reshape(3, 1)
weekly_sales = weekly_sales * (1.02 ** weeks)
print(weekly_sales)
# Out:
# [140 190 240 290 340]
# [ 7.   9.5 12.  14.5 17. ]
# [133.  180.5 216.  261.  306. ]
# [[133.     180.5    216.     261.     306.    ]
#  [135.66   184.11   220.32   266.22   312.12  ]
#  [138.3732 187.7922 224.7264 271.5444 318.3624]]

# %% [markdown]
# #Q4. Generate x values using np.linspace() from -10 to 10 with 100 points. Use each function from the list below and compute y values using NumPy:
#
# 1.   Y = x^2
# 2.   Y = sin(x)
# 3.   Y = e^x
# 4.   Y = log(|x| + 1)
#
# #Plot the chosen function using Matplotlib. Add title, labels, and grid for clarity.

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-10, 10, 100)

y1 = x**2
y2 = np.sin(x)
y3 = np.exp(x)
y4 = np.log(np.abs(x) + 1)

plt.figure(figsize=(10, 6))

plt.plot(x, y1, label=r'$y = x^2$', color='b')
# plt.plot(x, y2, label=r'$y = \sin(x)$', color='r')
# plt.plot(x, y3, label=r'$y = e^x$', color='g')
# plt.plot(x, y4, label=r'$y = \log(|x| + 1)$', color='purple')
# plt.title("Plots of Different Mathematical Functions", fontsize=14)
plt.xlabel("x values", fontsize=12)
plt.ylabel("y values", fontsize=12)

plt.grid(True, linestyle='--', alpha=0.6)
plt.legend(fontsize=12)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-10, 10, 100)
y2 = np.sin(x)
plt.figure(figsize=(10, 6))
plt.plot(x, y2, label=r'$y = \sin(x)$', color='r')
plt.xlabel("x values", fontsize=12)
plt.ylabel("y values", fontsize=12)

plt.grid(True, linestyle='--', alpha=0.6)
plt.legend(fontsize=12)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-10, 10, 100)
y3 = np.exp(x)
plt.figure(figsize=(10, 6))
plt.plot(x, y3, label=r'$y = e^x$', color='g')
plt.xlabel("x values", fontsize=12)
plt.ylabel("y values", fontsize=12)

plt.grid(True, linestyle='--', alpha=0.6)
plt.legend(fontsize=12)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-10, 10, 100)
y4 = np.log(np.abs(x) + 1)
plt.figure(figsize=(10, 6))
plt.plot(x, y4, label=r'$y = \log(|x| + 1)$', color='purple')
plt.xlabel("x values", fontsize=12)
plt.ylabel("y values", fontsize=12)

plt.grid(True, linestyle='--', alpha=0.6)
plt.legend(fontsize=12)

plt.show()
